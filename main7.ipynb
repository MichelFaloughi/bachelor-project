# %%
import pandas as pd

df = pd.read_excel('M0.4D0.0001E0.9A0.8_100x100_MC25_table_experiment.xlsx')
df
# Out:
#    Run ID  Iteration of first single cluster  Num clusters at end  \
# 0    1185                                NaN                    3
# 1    1186                                NaN                    2
#
#   Num particles per cluster at end  Total num particles in clusters at end  \
# 0                [1138, 919, 1226]                                    3283
# 1                      [3042, 203]                                    3245
#
#    Total num particles  Density of clustered particles
# 0                 4031                          0.8144
# 1                 4005                          0.8102

# %%
from ParticleSystem import ParticleSystem
import pandas as pd
import os

# Simulation parameters
WORLD_WIDTH = 100
WORLD_HEIGHT = 100
DOT_SIZE = 3
MIDDLE_CLUSTER_SIZE = -1
NUM_ITERATIONS = 5_000_000  # Experiment
INIT_REFRESH_RATE = 10
INIT_PAUSED_STATUS = False
min_cluster_size = 25

# First set of parameters
dct = {'alpha':0.8 , 'mu': 0.4, 'delta': 0.01  , 'epsilon': 0.9} # change density
DELTA, MU, EPSILON, ALPHA = dct['delta'], dct['mu'], dct['epsilon'], dct['alpha']

# Excel file name
file_name = f'M{MU}D{DELTA}E{EPSILON}A{ALPHA}_{WORLD_WIDTH}x{WORLD_HEIGHT}_MC{min_cluster_size}_table_experiment.xlsx'

# Ensure the Excel file has the correct column headers if it doesn't exist
if not os.path.isfile(file_name):
    df = pd.DataFrame(columns=[
        "Run ID", "Iteration of first single cluster", "Num clusters at end",
        "Num particles per cluster at end", "Total num particles in clusters at end",
        "Total num particles", "Density of clustered particles"
    ])
    df.to_excel(file_name, index=False, engine="openpyxl")  # Create the file with headers



# Run simulations
for i in range(200):
    world = ParticleSystem(
        WORLD_WIDTH, WORLD_HEIGHT, DELTA, MU, EPSILON, ALPHA,
        DOT_SIZE, MIDDLE_CLUSTER_SIZE, NUM_ITERATIONS,
        INIT_REFRESH_RATE, INIT_PAUSED_STATUS
    )

    # Run the simulation & collect results
    new_row = world.run_simulation_latest_experiement(
        min_cluster_size=min_cluster_size,
        refresh_rate=280, check_rate=25000, init_render_status=False
    )

    existing_df = pd.read_excel(file_name, engine="openpyxl") # Load the existing Excel file
    df_new = pd.DataFrame([new_row])

    excel_df = pd.concat([existing_df, df_new], ignore_index=True)
    excel_df.to_excel(file_name, index=False, engine="openpyxl")

    print(f'Finished World: {i}, Run ID: {int(world.id)}')
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\MichelFaloughi\AppData\Local\Temp\ipykernel_30488\1552978390.py:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   excel_df = pd.concat([existing_df, df_new], ignore_index=True)
# Finished World: 0, Run ID: 1592
# Finished World: 1, Run ID: 1595
# Finished World: 2, Run ID: 1599
# Finished World: 3, Run ID: 1603
# Finished World: 4, Run ID: 1607
# Finished World: 5, Run ID: 1611
# Finished World: 6, Run ID: 1615
# Finished World: 7, Run ID: 1620
# Finished World: 8, Run ID: 1624
# Finished World: 9, Run ID: 1628
# Finished World: 10, Run ID: 1632
# Finished World: 91, Run ID: 1955
# Finished World: 92, Run ID: 1959
# Finished World: 93, Run ID: 1963
# Finished World: 94, Run ID: 1967
# Finished World: 95, Run ID: 1971
# Finished World: 96, Run ID: 1975
# Finished World: 97, Run ID: 1979
# Finished World: 98, Run ID: 1983
# Finished World: 99, Run ID: 1987
# Finished World: 100, Run ID: 1991
# Finished World: 101, Run ID: 1995
# Finished World: 102, Run ID: 1999
# Finished World: 103, Run ID: 2003
# Finished World: 104, Run ID: 2007
# Finished World: 105, Run ID: 2011
# Finished World: 106, Run ID: 2015
# Finished World: 107, Run ID: 2019
# Finished World: 108, Run ID: 2023
# Finished World: 109, Run ID: 2027
# Finished World: 110, Run ID: 2031
# Finished World: 111, Run ID: 2035
# Finished World: 112, Run ID: 2039
# Finished World: 113, Run ID: 2043
# Finished World: 114, Run ID: 2047
# Finished World: 115, Run ID: 2051
# Finished World: 116, Run ID: 2055
# Finished World: 117, Run ID: 2059
# Finished World: 118, Run ID: 2063
# Finished World: 119, Run ID: 2067
# Finished World: 120, Run ID: 2071
# Finished World: 121, Run ID: 2075
# Finished World: 122, Run ID: 2079
# Finished World: 123, Run ID: 2083
# Finished World: 124, Run ID: 2087
# Finished World: 125, Run ID: 2091
# Finished World: 126, Run ID: 2095
# Finished World: 127, Run ID: 2099
# Finished World: 128, Run ID: 2103
# Finished World: 129, Run ID: 2108
# Finished World: 130, Run ID: 2113
# Finished World: 131, Run ID: 2117
# Finished World: 132, Run ID: 2121
# Finished World: 133, Run ID: 2125
# Finished World: 134, Run ID: 2129
# Finished World: 135, Run ID: 2133
# Finished World: 136, Run ID: 2137
# Finished World: 137, Run ID: 2141

# %%
from ParticleSystem import ParticleSystem
import pandas as pd
import os
import random

WORLD_WIDTH = 200
WORLD_HEIGHT = 200
DELTA = 0.0001
MU = 0.4
EPSILON = 0.9
ALPHA = 0.8
DOT_SIZE = 3
MIDDLE_CLUSTER_SIZE = -1
NUM_ITERATIONS = 10 ** 7 
INIT_REFRESH_RATE = 10
INIT_PAUSED_STATUS = False

min_cluster_size=100

file_name = f'M{MU}D{DELTA}E{EPSILON}A{ALPHA}_{WORLD_WIDTH}x{WORLD_HEIGHT}_MC{min_cluster_size}_num_cluster_tracker.xlsx'

# Ensure the Excel file has the correct column headers if it doesn't exist
if not os.path.isfile(file_name):
    df = pd.DataFrame(columns=["Iteration"])
    df.to_excel(file_name, index=False)  # Create the file with header

for i in range(200):

    world = ParticleSystem(
        WORLD_WIDTH,
        WORLD_HEIGHT,
        DELTA,
        MU,
        EPSILON,
        ALPHA,
        DOT_SIZE,
        MIDDLE_CLUSTER_SIZE,
        NUM_ITERATIONS,
        INIT_REFRESH_RATE,
        INIT_PAUSED_STATUS
    )

    iteration_num_clusters_df = world.run_simulation_get_num_clusters_at_each_iteration(
        min_cluster_size=min_cluster_size,
        refresh_rate=280, check_rate=25000, init_render_status=False
    )

    existing_df = pd.read_excel(file_name, engine="openpyxl") # Load the existing Excel file

    # Merge with the existing table (outer join to keep all iterations)
    merged_df = pd.merge(existing_df, iteration_num_clusters_df, on="Iteration", how="outer")

    # Save back to Excel
    merged_df.to_excel(file_name, index=False, engine="openpyxl")

    print(f'Finished World: {i} , Run id {world.id}')

# %%
# HERE, code to merge the 'iteration_num_clusters_df' to the excel file table. which looks like this


    # Iteration      ParticleSystem_1     ParticleSystem_2    Particle System_2
    #    x           num clusters at iteration x for each of the particle systems
    #    y           same but for iteration y etc
    #   ...


    # and each of the 'iteration_num_clusters_df' looks like this
    # Iteration    ParticleSystem_n
    # 
    # where 'n' is whatever the ID of the Particle System is

    # if you use the pd.merge function, make sure to specify how='outer'

# %%
# This is taking too long, (ie 300 by 300 is too much) This is for the 'first cluster' experiment


from ParticleSystem import ParticleSystem
import pandas as pd
import os
import random

WORLD_WIDTH = 300
WORLD_HEIGHT = 300
DELTA = 0.0001
MU = 0.4
EPSILON = 0.9
ALPHA = 0.8
DOT_SIZE = 3
MIDDLE_CLUSTER_SIZE = -1
NUM_ITERATIONS = 10 ** 18
INIT_REFRESH_RATE = 10
INIT_PAUSED_STATUS = False

file_name = f'M{MU}D{DELTA}E{EPSILON}A{ALPHA}_{WORLD_WIDTH}x{WORLD_HEIGHT}_first_cluster.xlsx'

# Ensure the Excel file has the correct column headers if it doesn't exist
if not os.path.isfile(file_name):
    df = pd.DataFrame(columns=["Run ID", "num iterations", 'MU', 'DELTA', 'EPSILON', 'ALPHA', 'WORLD_WIDTH', 'WORLD_HEIGHT'])
    df.to_excel(file_name, index=False)  # Create the file with headers

for i in range(200):

    # randomize check_rate
    curr_check_rate = int(random.uniform(50000, 55000))

    world = ParticleSystem(
        WORLD_WIDTH,
        WORLD_HEIGHT,
        DELTA,
        MU,
        EPSILON,
        ALPHA,
        DOT_SIZE,
        MIDDLE_CLUSTER_SIZE,
        NUM_ITERATIONS,
        INIT_REFRESH_RATE,
        INIT_PAUSED_STATUS
    )

    num_iterations_it_took = world.run_simulation_get_iteration_of_first_single_cluster(
        refresh_rate=280, check_rate=curr_check_rate, init_render_status=False, first_check=500000,
        min_cluster_size=500
    )

    # Append directly to the file (avoiding reading the whole file)
    new_data = pd.DataFrame([[world.id, num_iterations_it_took, MU, DELTA, EPSILON, ALPHA, WORLD_WIDTH, WORLD_HEIGHT]], 
                            columns=["Run ID", "num iterations", 'MU', 'DELTA', 'EPSILON', 'ALPHA', 'WORLD_WIDTH', 'WORLD_HEIGHT'])

    with pd.ExcelWriter(file_name, mode='a', if_sheet_exists='overlay', engine='openpyxl') as writer:
        new_data.to_excel(writer, index=False, header=False, startrow=writer.sheets['Sheet1'].max_row)

    print(f'Finished World: {i} , Run id {world.id}')
