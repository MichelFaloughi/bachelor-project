# %%
import pandas as pd
# Simulation parameters
WORLD_WIDTH = 100
WORLD_HEIGHT = 100

min_cluster_size = 25
dct =     {'alpha':0.8 , 'mu': 0.4, 'delta': 0.001 , 'epsilon': 0.9} # change density 2
DELTA, MU, EPSILON, ALPHA = dct['delta'], dct['mu'], dct['epsilon'], dct['alpha']

# Excel file name
file_name = f'M{MU}D{DELTA}E{EPSILON}A{ALPHA}_{WORLD_WIDTH}x{WORLD_HEIGHT}_MC{min_cluster_size}_table_experiment.xlsx'


df = pd.read_excel(file_name)   
print(df.to_string())

# quick dataframe dispaly
# Out:
#      Run ID  Iteration of first single cluster  Num clusters at end Num particles per cluster at end  Total num particles in clusters at end  Total num particles  Density of clustered particles
# 0      1634                             524999                    1                           [3312]                                    3312                 4066                          0.8146
# 1      1638                              99999                    1                           [3224]                                    3224                 4001                          0.8058
# 2      1642                             349999                    1                           [3168]                                    3168                 3918                          0.8086
# 3      1646                              74999                    1                           [3171]                                    3171                 3945                          0.8038
# ...

# %%
import pandas as pd

df = pd.read_excel('M0.4D0.0001E0.9A0.8_100x100_first_cluster.xlsx')
print(df)
# Out:
#      Run ID  num iterations
# 0       442           50001
# 1       444          290001
# 2       445          680001
# 3       447           95001
# 4       443         1025001
# ..      ...             ...
# 595    1041          770001
# 596    1042         1445001
# 597    1044           80001
# 598    1045          455001
# 599    1046          110001
#
# [600 rows x 2 columns]

# %%
import plotly.express as px

fig = px.scatter(df, x='Run ID', y='num iterations')
fig.show()

# %%
# and make sure to make the visualizations with bins hek you also kinda see the pmf/pdf
# of the distributions of the runs.

import plotly.express as px

fig = px.histogram(df, x="num iterations", nbins=500, title="Distribution of Number of Iterations")
fig.show()

# %%
####################################
## Num clusters at each iteration ##
####################################

import pandas as pd
import plotly.express as px

df = pd.read_excel('M0.4D0.0001E0.9A0.8_200x200_MC100_num_cluster_tracker.xlsx')
# print(df.to_string())

fig = px.line(df, x='Iteration', y=[f'ParticleSystem_{i}' for i in range(1116,1158)])
fig.show()

# %%
####################################
## Num clusters at each iteration ##
####################################

import pandas as pd
import plotly.express as px

df = pd.read_excel('M0.4D0.0001E0.9A0.8_100x100_MC50_num_cluster_tracker.xlsx')

#print(df.to_string())


fig = px.line(df, x='Iteration', y=[f'ParticleSystem_{i}' for i in range(1063,1113)])
fig.show()

# %%
# For the plot above, you can comment that some clusters take long time and are stuck at a specfic number of clusters, before converging back to one.
# It's probably this that makes these extreme run times

# %%
db = pd.read_excel('ParticleSystem_database.xlsx')
db
# Out:
#         ID   mu   delta  epsilon  alpha  width  height  num_particles  \
# 0     1058  0.4  0.0001      0.9    0.8    300     300          35999
# 1     1059  0.4  0.0001      0.9    0.8    300     300          36107
# 2     1060  0.4  0.0001      0.9    0.8    300     300          35962
# 3     1061  0.4  0.0001      0.9    0.8    300     300          35964
# 4     1062  0.4  0.0001      0.9    0.8    100     100           4047
# ...    ...  ...     ...      ...    ...    ...     ...            ...
# 1571  2633  0.4  0.0001      0.5    0.8    100     100           4066
# 1572  2634  0.4  0.0001      0.5    0.8    100     100           3960
# 1573  2635  0.4  0.0001      0.5    0.8    100     100           3924
# 1574  2636  0.4  0.0001      0.5    0.8    100     100           4055
# 1575  2637  0.4  0.0001      0.5    0.8    100     100           3947
#
#            num_iterations
# 0     1000000000000000000
# 1     1000000000000000000
# 2     1000000000000000000
# ...
